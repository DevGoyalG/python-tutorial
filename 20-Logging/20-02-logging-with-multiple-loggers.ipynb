# %% [markdown]
# ## Logging with Multiple Loggers

# %% [markdown]
# You can create multiple loggers for different parts of your application.

# %%
import logging

# %%
### Create a logger for module1
logger1 = logging.getLogger("module1")
logger1.setLevel(logging.DEBUG)

### Create a logger for module1
logger2 = logging.getLogger("module2")
logger2.setLevel(logging.WARNING)

### Configuring logging
logging.basicConfig(
    level = logging.DEBUG,
    format='%(asctime)s - %(name)s - %(levelname)s - %(message)s',
    datefmt= '%Y-%m-%d %H:%M:%S',
    force=True
)

# %%
### log messages with different loggers
logger1.debug("This is a debug message for module1")
logger2.warning("This is a warning message for module1")
logger2.error("This is an error message")
# Out:
# 2026-09-20 16:54:35 - module1 - DEBUG - This is a debug message for module1
# 2026-09-20 16:54:35 - module2 - WARNING - This is a warning message for module1
# 2026-09-20 16:54:35 - module2 - ERROR - This is an error message
